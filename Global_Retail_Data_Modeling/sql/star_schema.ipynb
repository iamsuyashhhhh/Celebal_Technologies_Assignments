# %%
# %sql
DESCRIBE TABLE gold.dim_customer;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
DESCRIBE TABLE gold.dim_product;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
DESCRIBE TABLE gold.dim_date;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>date_sk</td><td>int</td><td>null</td></tr><tr><td>full_date</td><td>date</td><td>null</td></tr><tr><td>day</td><td>int</td><td>null</td></tr><tr><td>month</td><td>int</td><td>null</td></tr><tr><td>month_name</td><td>string</td><td>null</td></tr><tr><td>quarter</td><td>int</td><td>null</td></tr><tr><td>year</td><td>int</td><td>null</td></tr><tr><td>week</td><td>int</td><td>null</td></tr><tr><td>day_name</td><td>string</td><td>null</td></tr><tr><td>is_weekend</td><td>boolean</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE TABLE gold.dim_geography;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>geo_sk</td><td>int</td><td>null</td></tr><tr><td>customer_key</td><td>string</td><td>null</td></tr><tr><td>country</td><td>string</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE TABLE gold.fact_sales;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>order_number</td><td>string</td><td>null</td></tr><tr><td>customer_sk</td><td>int</td><td>null</td></tr><tr><td>product_sk</td><td>int</td><td>null</td></tr><tr><td>order_date</td><td>int</td><td>null</td></tr><tr><td>ship_date</td><td>int</td><td>null</td></tr><tr><td>due_date</td><td>int</td><td>null</td></tr><tr><td>quantity</td><td>int</td><td>null</td></tr><tr><td>price</td><td>double</td><td>null</td></tr><tr><td>sales_amount</td><td>double</td><td>null</td></tr></tbody></table></div>
