# %%
from pyspark.sql.functions import *

# %%
existing_orders = (spark.table("silver.sales")
    .select("order_number", "product_key", "customer_id")
    .limit(2)
    .collect()
)

# %%
incremental_data = [
    (
        existing_orders[0]["order_number"],
        existing_orders[0]["product_key"],
        existing_orders[0]["customer_id"],
        20140101,
        20140103,
        20140106,
        5000,
        2,
        2500
    ),
    (
        existing_orders[1]["order_number"],
        existing_orders[1]["product_key"],
        existing_orders[1]["customer_id"],
        20140102,
        20140104,
        20140107,
        4200,
        3,
        1400
    ),
    (
        "SO999901",
        "BK-R93R-44",
        25001,
        20140102,
        20140104,
        20140107,
        3200,
        2,
        1600
    ),
    (
        "SO999902",
        "BK-R93R-48",
        25002,
        20140105,
        20140107,
        20140110,
        1800,
        1,
        1800
    ),
    (
        "SO999903",
        "BK-M82S-44",
        25003,
        20140106,
        20140108,
        20140111,
        4100,
        2,
        2050
    ),
    (
        "SO999904",
        "BK-R50R-52",
        25004,
        20140108,
        20140110,
        20140113,
        2800,
        1,
        2800
    )
]

# %%
columns = [
    "sls_ord_num",
    "sls_prd_key",
    "sls_cust_id",
    "sls_order_dt",
    "sls_ship_dt",
    "sls_due_dt",
    "sls_sales",
    "sls_quantity",
    "sls_price"
]

# %%
incremental_df = spark.createDataFrame(incremental_data,columns)

# %%
display(incremental_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sls_ord_num</th><th>sls_prd_key</th><th>sls_cust_id</th><th>sls_order_dt</th><th>sls_ship_dt</th><th>sls_due_dt</th><th>sls_sales</th><th>sls_quantity</th><th>sls_price</th></tr></thead><tbody><tr><td>SO43720</td><td>BK-R93R-44</td><td>13264</td><td>20140101</td><td>20140103</td><td>20140106</td><td>5000</td><td>2</td><td>2500</td></tr><tr><td>SO43734</td><td>BK-R93R-48</td><td>27604</td><td>20140102</td><td>20140104</td><td>20140107</td><td>4200</td><td>3</td><td>1400</td></tr><tr><td>SO999901</td><td>BK-R93R-44</td><td>25001</td><td>20140102</td><td>20140104</td><td>20140107</td><td>3200</td><td>2</td><td>1600</td></tr><tr><td>SO999902</td><td>BK-R93R-48</td><td>25002</td><td>20140105</td><td>20140107</td><td>20140110</td><td>1800</td><td>1</td><td>1800</td></tr><tr><td>SO999903</td><td>BK-M82S-44</td><td>25003</td><td>20140106</td><td>20140108</td><td>20140111</td><td>4100</td><td>2</td><td>2050</td></tr><tr><td>SO999904</td><td>BK-R50R-52</td><td>25004</td><td>20140108</td><td>20140110</td><td>20140113</td><td>2800</td><td>1</td><td>2800</td></tr></tbody></table></div>

# %%
incremental_df.write \
.mode("overwrite") \
.option("header", True) \
.csv("/Volumes/workspace/default/retail_data/sales_incremental.csv")

# %%
print("Incremental Dataset Generated Successfully")
print(f"Total Records : {incremental_df.count()}")
display(incremental_df)
# Out:
# Incremental Dataset Generated Successfully
# Total Records : 6
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sls_ord_num</th><th>sls_prd_key</th><th>sls_cust_id</th><th>sls_order_dt</th><th>sls_ship_dt</th><th>sls_due_dt</th><th>sls_sales</th><th>sls_quantity</th><th>sls_price</th></tr></thead><tbody><tr><td>SO43720</td><td>BK-R93R-44</td><td>13264</td><td>20140101</td><td>20140103</td><td>20140106</td><td>5000</td><td>2</td><td>2500</td></tr><tr><td>SO43734</td><td>BK-R93R-48</td><td>27604</td><td>20140102</td><td>20140104</td><td>20140107</td><td>4200</td><td>3</td><td>1400</td></tr><tr><td>SO999901</td><td>BK-R93R-44</td><td>25001</td><td>20140102</td><td>20140104</td><td>20140107</td><td>3200</td><td>2</td><td>1600</td></tr><tr><td>SO999902</td><td>BK-R93R-48</td><td>25002</td><td>20140105</td><td>20140107</td><td>20140110</td><td>1800</td><td>1</td><td>1800</td></tr><tr><td>SO999903</td><td>BK-M82S-44</td><td>25003</td><td>20140106</td><td>20140108</td><td>20140111</td><td>4100</td><td>2</td><td>2050</td></tr><tr><td>SO999904</td><td>BK-R50R-52</td><td>25004</td><td>20140108</td><td>20140110</td><td>20140113</td><td>2800</td><td>1</td><td>2800</td></tr></tbody></table></div>
